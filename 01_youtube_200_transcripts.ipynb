# %% [markdown]
# # 01_youtube_200_transcripts.ipynb
# Scrape 200 YouTube videos + English auto-subtitles
# Canadian far-right / extremism policy

# %%
import os, yt_dlp, pandas as pd
from googleapiclient.discovery import build
from pathlib import Path

API_KEY = os.getenv('YOUTUBE_API_KEY')
RAW_DIR = Path("data/raw")
RAW_DIR.mkdir(parents=True, exist_ok=True)

QUERIES = [
    "canada far-right policy 2024",
    "canadian violent extremism research",
    "deradicalization canada policy",
    "online radicalization youth canada",
    "extremist movements canada policy"
]

# %%
youtube = build('youtube', 'v3', developerKey=API_KEY)
videos = []

for query in QUERIES:
    request = youtube.search().list(q=query, part='snippet', maxResults=40, type='video')
    response = request.execute()
    for item in response['items']:
        videos.append({
            'video_id': item['id']['videoId'],
            'title': item['snippet']['title'],
            'channel': item['snippet']['channelTitle'],
            'published': item['snippet']['publishedAt'],
            'query_used': query
        })

print(f"Found {len(videos)} videos ready for subtitle download")
df = pd.DataFrame(videos)
df.to_csv("master_dataset.csv", index=False)
# Out:
# Found 200 videos ready for subtitle download

# %%
# CORRECTED VERSION — works 100%
ydl_opts = {
    'writeautomaticsub': True,
    'skip_download': True,
    'subtitleslangs': ['en'],
    'subtitlesformat': 'vtt',
    'quiet': False,
    'retries': 10,
    'sleep_interval': 3,
    'extractor_args': {'youtube': {'player_client': ['android']}},
    'outtmpl': str(RAW_DIR / '%(id)s.%(ext)s')
}

# Fixed line: videos is a list of dicts → use list comprehension correctly
with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    urls = [f"https://www.youtube.com/watch?v={video['video_id']}" for video in videos]
    ydl.download(urls)

print("All subtitle downloads finished!")
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=9LHCC4TteGU
# [youtube] 9LHCC4TteGU: Downloading webpage
# [youtube] 9LHCC4TteGU: Downloading android player API JSON
# WARNING: [youtube] 9LHCC4TteGU: android client https formats require a GVS PO Token which was not provided. They will be skipped as they may yield HTTP Error 403. You can manually pass a GVS PO Token for this client with --extractor-args "youtube:po_token=android.gvs+XXX". For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/PO-Token-Guide
# [info] 9LHCC4TteGU: Downloading subtitles: en
# [info] 9LHCC4TteGU: Downloading 1 format(s): 18
# [info] Writing video subtitles to: data/raw/9LHCC4TteGU.en.vtt
# [download] Destination: data/raw/9LHCC4TteGU.en.vtt
# [download] 100% of    7.09KiB in 00:00:00 at 31.68KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=7EHVS1Su5Po
# [youtube] 7EHVS1Su5Po: Downloading webpage
# [youtube] 7EHVS1Su5Po: Downloading android player API JSON
# WARNING: [youtube] 7EHVS1Su5Po: android client https formats require a GVS PO Token which was not provided. They will be skipped as they may yield HTTP Error 403. You can manually pass a GVS PO Token for this client with --extractor-args "youtube:po_token=android.gvs+XXX". For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/PO-Token-Guide
# [info] 7EHVS1Su5Po: Downloading subtitles: en
# [info] 7EHVS1Su5Po: Downloading 1 format(s): 18
# [info] Writing video subtitles to: data/raw/7EHVS1Su5Po.en.vtt
# [download] Destination: data/raw/7EHVS1Su5Po.en.vtt
# [download] 100% of   13.25KiB in 00:00:00 at 115.17KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=QThBwP2KV3k
# [youtube] QThBwP2KV3k: Downloading webpage
# [youtube] QThBwP2KV3k: Downloading android player API JSON
# WARNING: [youtube] QThBwP2KV3k: android client https formats require a GVS PO Token which was not provided. They will be skipped as they may yield HTTP Error 403. You can manually pass a GVS PO Token for this client with --extractor-args "youtube:po_token=android.gvs+XXX". For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/PO-Token-Guide
# [info] QThBwP2KV3k: Downloading subtitles: en
# [info] QThBwP2KV3k: Downloading 1 format(s): 18
# [info] Writing video subtitles to: data/raw/QThBwP2KV3k.en.vtt
# [download] Destination: data/raw/QThBwP2KV3k.en.vtt
# [download] 100% of   58.71KiB in 00:00:00 at 319.43KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=56w54X-gLig
# [youtube] 56w54X-gLig: Downloading webpage
# [youtube] 56w54X-gLig: Downloading android player API JSON
# WARNING: [youtube] 56w54X-gLig: android client https formats require a GVS PO Token which was not provided. They will be skipped as they may yield HTTP Error 403. You can manually pass a GVS PO Token for this client with --extractor-args "youtube:po_token=android.gvs+XXX". For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/PO-Token-Guide
# [info] 56w54X-gLig: Downloading subtitles: en
# [info] 56w54X-gLig: Downloading 1 format(s): 18
# [info] Writing video subtitles to: data/raw/56w54X-gLig.en.vtt
# [download] Destination: data/raw/56w54X-gLig.en.vtt
# [download] 100% of  405.98KiB in 00:00:00 at 1.21MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=3XcN3DCDqFs
# [youtube] 3XcN3DCDqFs: Downloading webpage
# [youtube] 3XcN3DCDqFs: Downloading android player API JSON
# WARNING: [youtube] 3XcN3DCDqFs: android client https formats require a GVS PO Token which was not provided. They will be skipped as they may yield HTTP Error 403. You can manually pass a GVS PO Token for this client with --extractor-args "youtube:po_token=android.gvs+XXX". For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/PO-Token-Guide
# [info] 3XcN3DCDqFs: Downloading subtitles: en
# [info] 3XcN3DCDqFs: Downloading 1 format(s): 18
# [info] Writing video subtitles to: data/raw/3XcN3DCDqFs.en.vtt
# [download] Destination: data/raw/3XcN3DCDqFs.en.vtt
# [download] 100% of    5.24KiB in 00:00:00 at 33.40KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=dZxvVo1pd0o
# [youtube] dZxvVo1pd0o: Downloading webpage
# [youtube] dZxvVo1pd0o: Downloading android player API JSON
# WARNING: [youtube] dZxvVo1pd0o: android client https formats require a GVS PO Token which was not provided. They will be skipped as they may yield HTTP Error 403. You can manually pass a GVS PO Token for this client with --extractor-args "youtube:po_token=android.gvs+XXX". For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/PO-Token-Guide
# [info] dZxvVo1pd0o: Downloading subtitles: en
# [info] dZxvVo1pd0o: Downloading 1 format(s): 18
# [info] Writing video subtitles to: data/raw/dZxvVo1pd0o.en.vtt
# [download] Destination: data/raw/dZxvVo1pd0o.en.vtt
# [download] 100% of    9.61KiB in 00:00:00 at 70.01KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=_m1FBOIALus
# [youtube] _m1FBOIALus: Downloading webpage
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 17
#      15 with yt_dlp.YoutubeDL(ydl_opts) as ydl:
#      16     urls = [f"https://www.youtube.com/watch?v={video['video_id']}" for video in videos]
# ---> 17     ydl.download(urls)
#      19 print("All subtitle downloads finished!")
#
# File /opt/anaconda3/lib/python3.13/site-packages/yt_dlp/YoutubeDL.py:3662, in YoutubeDL.download(self, url_list)
#    3659     raise SameFileError(outtmpl)
#    3661 for url in url_list:
# -> 3662     self.__download_wrapper(self.extract_info)(
#    3663         url, force_generic_extractor=self.params.get('force_generic_extractor', False))
#    3665 return self._download_retcode
#
# File /opt/anaconda3/lib/python3.13/site-packages/yt_dlp/YoutubeDL.py:3635, in YoutubeDL.__download_wrapper.<locals>.wrapper(*args, **kwargs)
#    3632 @functools.wraps(func)
#    3633 def wrapper(*args, **kwargs):
#    3634     try:
# -> 3635         res = func(*args, **kwargs)
#    3636     except CookieLoadError:
#    3637         raise
#
# File /opt/anaconda3/lib/python3.13/site-packages/yt_dlp/YoutubeDL.py:1685, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1683             raise ExistingVideoReached
#    1684         break
# -> 1685     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1686 else:
#    1687     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File /opt/anaconda3/lib/python3.13/site-packages/yt_dlp/YoutubeDL.py:1696, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1694 while True:
#    1695     try:
# -> 1696         return func(self, *args, **kwargs)
#    1697     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1698         raise
#
# File /opt/anaconda3/lib/python3.13/site-packages/yt_dlp/YoutubeDL.py:1831, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1828 self._apply_header_cookies(url)
#    1830 try:
# -> 1831     ie_result = ie.extract(url)
#    1832 except UserNotLive as e:
#    1833     if process:
#
# File /opt/anaconda3/lib/python3.13/site-packages/yt_dlp/extractor/common.py:762, in InfoExtractor.extract(self, url)
#     759 self.initialize()
#     760 self.to_screen('Extracting URL: %s' % (
#     761     url if self.get_param('verbose') else truncate_string(url, 100, 20)))
# --> 762 ie_result = self._real_extract(url)
#     763 if ie_result is None:
#     764     return None
#
# File /opt/anaconda3/lib/python3.13/site-packages/yt_dlp/extractor/youtube/_video.py:3722, in YoutubeIE._real_extract(self, url)
#    3719 webpage_url = base_url + 'watch?v=' + video_id
#    3720 webpage_client = 'web'
# -> 3722 webpage, webpage_ytcfg, initial_data, is_premium_subscriber, player_responses, player_url = self._initial_extract(
#    3723     url, smuggled_data, webpage_url, webpage_client, video_id)
#    3725 playability_statuses = traverse_obj(
#    3726     player_responses, (..., 'playabilityStatus'), expected_type=dict)
#    3728 trailer_video_id = get_first(
#    3729     playability_statuses,
#    3730     ('errorScreen', 'playerLegacyDesktopYpcTrailerRenderer', 'trailerVideoId'),
#    3731     expected_type=str)
#
# File /opt/anaconda3/lib/python3.13/site-packages/yt_dlp/extractor/youtube/_video.py:3699, in YoutubeIE._initial_extract(self, url, smuggled_data, webpage_url, webpage_client, video_id)
#    3697 def _initial_extract(self, url, smuggled_data, webpage_url, webpage_client, video_id):
#    3698     # This function is also used by live-from-start refresh
# -> 3699     webpage = self._download_initial_webpage(webpage_url, webpage_client, video_id)
#    3700     webpage_ytcfg = self.extract_ytcfg(video_id, webpage) or self._get_default_ytcfg(webpage_client)
#    3702     initial_data = self._download_initial_data(video_id, webpage, webpage_client, webpage_ytcfg)
#
# File /opt/anaconda3/lib/python3.13/site-packages/yt_dlp/extractor/youtube/_video.py:3641, in YoutubeIE._download_initial_webpage(self, webpage_url, webpage_client, video_id)
#    3639     if pp:
#    3640         query['pp'] = pp
# -> 3641     webpage = self._download_webpage_with_retries(
#    3642         webpage_url, video_id, query=query,
#    3643         headers=traverse_obj(self._get_default_ytcfg(webpage_client), {
#    3644             'User-Agent': ('INNERTUBE_CONTEXT', 'client', 'userAgent', {str}),
#    3645         }))
#    3646 return webpage
#
# File /opt/anaconda3/lib/python3.13/site-packages/yt_dlp/extractor/youtube/_base.py:979, in YoutubeBaseInfoExtractor._download_webpage_with_retries(self, retry_fatal, retry_on_status, *args, **kwargs)
#     977 for retry in self.RetryManager(fatal=retry_fatal):
#     978     try:
# --> 979         return self._download_webpage(*args, **kwargs)
#     980     except ExtractorError as e:
#     981         if isinstance(e.cause, network_exceptions):
#
# File /opt/anaconda3/lib/python3.13/site-packages/yt_dlp/extractor/common.py:1199, in InfoExtractor._download_webpage(self, url_or_request, video_id, note, errnote, fatal, tries, timeout, *args, **kwargs)
#    1197 while True:
#    1198     try:
# -> 1199         return self.__download_webpage(url_or_request, video_id, note, errnote, None, fatal, *args, **kwargs)
#    1200     except IncompleteRead as e:
#    1201         try_count += 1
#
# File /opt/anaconda3/lib/python3.13/site-packages/yt_dlp/extractor/common.py:1150, in InfoExtractor.__create_download_methods.<locals>.download_content(self, url_or_request, video_id, note, errnote, transform_source, fatal, encoding, data, headers, query, expected_status, impersonate, require_impersonation)
#    1148     kwargs.pop('transform_source')
#    1149 # The method is fetched by name so subclasses can override _download_..._handle
# -> 1150 res = getattr(self, download_handle.__name__)(url_or_request, video_id, **kwargs)
#    1151 return res if res is False else res[0]
#
# File /opt/anaconda3/lib/python3.13/site-packages/yt_dlp/extractor/common.py:979, in InfoExtractor._download_webpage_handle(self, url_or_request, video_id, note, errnote, fatal, encoding, data, headers, query, expected_status, impersonate, require_impersonation)
#     977     assert not fatal
#     978     return False
# --> 979 content = self._webpage_read_content(urlh, url_or_request, video_id, note, errnote, fatal,
#     980                                      encoding=encoding, data=data)
#     981 if content is False:
#     982     assert not fatal
#
# File /opt/anaconda3/lib/python3.13/site-packages/yt_dlp/extractor/common.py:1042, in InfoExtractor._webpage_read_content(self, urlh, url_or_request, video_id, note, errnote, fatal, prefix, encoding, data)
#    1039 def _webpage_read_content(self, urlh, url_or_request, video_id, note=None, errnote=None, fatal=True,
#    1040                           prefix=None, encoding=None, data=None):
#    1041     try:
# -> 1042         webpage_bytes = urlh.read()
#    1043     except TransportError as err:
#    1044         errmsg = f'{video_id}: Error reading response: {err.msg}'
#
# File /opt/anaconda3/lib/python3.13/site-packages/yt_dlp/networking/_requests.py:134, in RequestsResponseAdapter.read(self, amt)
#     132 def read(self, amt: int | None = None):
#     133     try:
# --> 134         data = self._real_read(amt)
#     135         if self.fp.closed:
#     136             self.close()
#
# File /opt/anaconda3/lib/python3.13/site-packages/yt_dlp/networking/_requests.py:128, in RequestsResponseAdapter._real_read(self, amt)
#     125 if amt is None:
#     126     # compat: py3.9: Python 3.9 preallocates the whole read buffer, read in chunks
#     127     read_chunk = functools.partial(self.fp.read, 1 << 20, decode_content=True)
# --> 128     return b''.join(iter(read_chunk, b''))
#     129 # Interact with urllib3 response directly.
#     130 return self.fp.read(amt, decode_content=True)
#
# File /opt/anaconda3/lib/python3.13/site-packages/urllib3/response.py:1101, in HTTPResponse.read(self, amt, decode_content, cache_content)
#    1098     if len(self._decoded_buffer) >= amt:
#    1099         return self._decoded_buffer.get(amt)
# -> 1101 data = self._raw_read(amt)
#    1103 flush_decoder = amt is None or (amt != 0 and not data)
#    1105 if (
#    1106     not data
#    1107     and len(self._decoded_buffer) == 0
#    1108     and not (self._decoder and self._decoder.has_unconsumed_tail)
#    1109 ):
#
# File /opt/anaconda3/lib/python3.13/site-packages/urllib3/response.py:1017, in HTTPResponse._raw_read(self, amt, read1)
#    1014 fp_closed = getattr(self._fp, "closed", False)
#    1016 with self._error_catcher():
# -> 1017     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#    1018     if amt is not None and amt != 0 and not data:
#    1019         # Platform-specific: Buggy versions of Python.
#    1020         # Close the connection when no data is returned
#    (...)   1025         # not properly close the connection in all cases. There is
#    1026         # no harm in redundantly calling close.
#    1027         self._fp.close()
#
# File /opt/anaconda3/lib/python3.13/site-packages/urllib3/response.py:1000, in HTTPResponse._fp_read(self, amt, read1)
#     997     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     998 else:
#     999     # StringIO doesn't like amt=None
# -> 1000     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /opt/anaconda3/lib/python3.13/http/client.py:473, in HTTPResponse.read(self, amt)
#     470     return b""
#     472 if self.chunked:
# --> 473     return self._read_chunked(amt)
#     475 if amt is not None and amt >= 0:
#     476     if self.length is not None and amt > self.length:
#     477         # clip the read to the "end of response"
#
# File /opt/anaconda3/lib/python3.13/http/client.py:597, in HTTPResponse._read_chunked(self, amt)
#     595 value = []
#     596 try:
# --> 597     while (chunk_left := self._get_chunk_left()) is not None:
#     598         if amt is not None and amt <= chunk_left:
#     599             value.append(self._safe_read(amt))
#
# File /opt/anaconda3/lib/python3.13/http/client.py:579, in HTTPResponse._get_chunk_left(self)
#     577     self._safe_read(2)  # toss the CRLF at the end of the chunk
#     578 try:
# --> 579     chunk_left = self._read_next_chunk_size()
#     580 except ValueError:
#     581     raise IncompleteRead(b'')
#
# File /opt/anaconda3/lib/python3.13/http/client.py:539, in HTTPResponse._read_next_chunk_size(self)
#     537 def _read_next_chunk_size(self):
#     538     # Read the next chunk size from the file
# --> 539     line = self.fp.readline(_MAXLINE + 1)
#     540     if len(line) > _MAXLINE:
#     541         raise LineTooLong("chunk size")
#
# File /opt/anaconda3/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File /opt/anaconda3/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/anaconda3/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import glob
vtt_files = glob.glob("data/raw/*.en.vtt")
print(f"Successfully downloaded {len(vtt_files)} English subtitle files")
# Out:
# Successfully downloaded 6 English subtitle files
